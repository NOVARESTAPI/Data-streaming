# %% [markdown]
# <a href="https://colab.research.google.com/github/NOVARESTAPI/Data-streaming/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install numpy==1.26.4
# !pip install numpy==2.0
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting numpy==2.0
#   Downloading numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 4.2 MB/s eta 0:00:00
# Downloading numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 60.5 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-ta 0.4.67b0 requires numpy>=2.2.6, but you have numpy 2.0.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# Successfully installed numpy-2.0.0

# %%
# !pip install pandas_ta
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting pandas_ta
#   Using cached pandas_ta-0.4.67b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Using cached numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Using cached numpy-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pandas>=2.3.2 (from pandas_ta)
#   Using cached pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from pandas_ta) (4.67.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Using cached llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Using cached pandas_ta-0.4.67b0-py3-none-any.whl (240 kB)
# Using cached numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Using cached pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
# Using cached llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: numpy, llvmlite, pandas, numba, pandas_ta
#   Attempting uninstall: llvmlite
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: pandas
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# Successfully installed llvmlite-0.44.0 numba-0.61.2 numpy pandas-2.3.2 pandas_ta-0.4.67b0

# %%
pip install pyfolio-reloaded
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Collecting pyfolio-reloaded
#   Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pyfolio-reloaded)
#   Using cached numpy-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: pandas<3.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (2.3.2)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (3.10.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (1.16.1)
# Requirement already satisfied: scikit-learn>=0.16.1 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (1.6.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (0.13.2)
# Collecting empyrical-reloaded>=0.5.9 (from pyfolio-reloaded)
#   Downloading empyrical_reloaded-0.5.12-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded) (1.4.2)
# Collecting peewee<3.17.4 (from empyrical-reloaded>=0.5.9->pyfolio-reloaded)
#   Downloading peewee-3.17.3.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 28.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio-reloaded)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.5.0->pyfolio-reloaded) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.16.1->pyfolio-reloaded) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.16.1->pyfolio-reloaded) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio-reloaded) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio-reloaded) (1.17.0)
# Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 81.8 MB/s eta 0:00:00
# Downloading empyrical_reloaded-0.5.12-py3-none-any.whl (33 kB)
# Downloading numpy-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 95.4 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.1 MB/s eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.3-py3-none-any.whl size=138487 sha256=2fbcc389948b34ae594b1be07b6452895ce4e04372c99ba08b5f7087d9afee89
#   Stored in directory: /root/.cache/pip/wheels/39/c7/dd/909d267742f7fbb941ff081dacd661f622a0b4eb38f667b84b
# Successfully built peewee
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
# Installing collected packages: peewee, numpy, jedi, empyrical-reloaded, pyfolio-reloaded
#   Attempting uninstall: peewee
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.12/dist-packages)
#     Found existing installation: peewee 3.18.2
#     Uninstalling peewee-3.18.2:
#       Successfully uninstalled peewee-3.18.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.3.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.2 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# Successfully installed empyrical-reloaded-0.5.12 jedi-0.19.2 numpy-2.3.2 peewee-3.17.3 pyfolio-reloaded-0.9.9

# %%
import os
import numpy as np
import pandas as pd
import pandas_ta as ta
import pyfolio as pf
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from tensorflow import keras
from tabulate import tabulate

# -------------------------------------------------------------------------------------
# Step 1: Install Libraries (for completeness, but you have them commented out)
# -------------------------------------------------------------------------------------

# os.system("pip install numpy==1.23.0")
# os.system("pip install pandas==1.3.5")

# -------------------------------------------------------------------------------------
# Step 2: Import Dataset and Plot
# -------------------------------------------------------------------------------------

ticker = 'O39.SI'
data = yf.download(ticker, start='2002-01-01', end='2026-01-01')
data.columns = data.columns.droplevel(level=1)

# Display the dataset using tabulate
print(tabulate(data.head(), headers='keys', tablefmt='pretty'))

# Plot Close Price
data.Close.plot(figsize=(18, 5), color='b')
plt.ylabel('Close Price')
plt.xlabel('Date')
plt.title(f'{ticker} Close Price')
plt.show()

# -------------------------------------------------------------------------------------
# Step 3: Define Features and Target
# -------------------------------------------------------------------------------------

def get_target_features(data):
    # Define Features (X)
    data['PCT_CHANGE'] = data['Close'].pct_change()
    data['VOLATILITY'] = data['PCT_CHANGE'].rolling(14).std() * 100
    data['RSI'] = ta.rsi(data['Close'], length=14)  # RSI using pandas_ta
    adx = ta.adx(data['High'], data['Low'], data['Close'], length=14)  # ADX using pandas_ta
    data['ADX'] = adx['ADX_14']  # Extract ADX from the result
    data['SMA'] = ta.sma(data['Close'], length=14)  # Simple Moving Average

    # Correlation: Correlation between 'Close' and its 14-day moving average (SMA)
    data['CORR'] = data['Close'].rolling(window=14).corr(data['SMA'])  # Correlation using pandas_ta

    # Define Target (y)
    data['Returns_4_Tmrw'] = data['Close'].pct_change().shift(-1)
    data['Actual_Signal'] = np.where(data['Returns_4_Tmrw'] > 0, 1, 0)

    data = data.dropna()
    return data['Actual_Signal'], data[['VOLATILITY', 'RSI', 'ADX', 'CORR']]

y, X = get_target_features(data)

# Display Features and Target using tabulate
df_combined = pd.DataFrame({
    "VOLATILITY": X['VOLATILITY'],
    "RSI": X['RSI'],
    "ADX": X['ADX'],
    "CORR": X['CORR'],
    "Returns_4_Tmrw": data['Returns_4_Tmrw'],  # Added Returns_4_Tmrw here
    "Actual_Signal": y
})
df_combined = df_combined.dropna().round(5)  # Round to 5 decimal places
print(tabulate(df_combined.head(10), headers='keys', tablefmt='pretty'))

# -------------------------------------------------------------------------------------
# Step 4: Train Test Split
# -------------------------------------------------------------------------------------

# Split Data
split = int(0.8 * len(X))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# -------------------------------------------------------------------------------------
# Step 5: Scaling
# -------------------------------------------------------------------------------------

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# -------------------------------------------------------------------------------------
# Step 6: Define and Train the Model (ANN)
# -------------------------------------------------------------------------------------

model = Sequential()
model.add(Dense(units=128, activation='relu', input_dim=X.shape[1]))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

model.summary()

# -------------------------------------------------------------------------------------
# Step 7: Plot the Model Architecture
# -------------------------------------------------------------------------------------

keras.utils.plot_model(model, 'model.png', show_shapes=True)

# Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# Train Model
history = model.fit(X_train, y_train, batch_size=20, epochs=30, validation_data=(X_test, y_test))

# -------------------------------------------------------------------------------------
# Step 8: Plot Training Metrics
# -------------------------------------------------------------------------------------

bce = history.history['loss']
val_bce = history.history['val_loss']
epoch = range(len(bce))

plt.plot(epoch, bce, label='Binary Crossentropy')
plt.plot(epoch, val_bce, label='Validation Binary Crossentropy')
plt.xlabel('Epoch')
plt.ylabel('Binary Crossentropy')
plt.legend()

acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
plt.plot(epoch, acc, label='Binary Accuracy')
plt.plot(epoch, val_acc, label='Validation Binary Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# -------------------------------------------------------------------------------------
# Step 9: Confusion Matrix and Accuracy Metrics
# -------------------------------------------------------------------------------------

from sklearn import metrics

def get_metrics(y_test, predicted):
    confusion_matrix_data = metrics.confusion_matrix(y_test, predicted)
    print(tabulate(confusion_matrix_data, headers=['Predicted No Position', 'Predicted Long Position'], tablefmt='pretty'))
    print('\n\n\n', metrics.classification_report(y_test, predicted))

y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)
get_metrics(y_test, y_pred)

# -------------------------------------------------------------------------------------
# Step 10: Backtesting Our Model
# -------------------------------------------------------------------------------------

df = yf.download(ticker, start='2002-01-01', end='2026-01-01')
df.columns = df.columns.droplevel(level=1)

df['PCT_CHANGE'] = df['Close'].pct_change()
df['VOLATILITY'] = df['PCT_CHANGE'].rolling(14).std() * 100
df['RSI'] = ta.rsi(df['Close'], length=14)  # RSI using pandas_ta
df['ADX'] = ta.adx(df['High'], df['Low'], df['Close'], length=14)['ADX_14']  # ADX using pandas_ta
df['SMA'] = ta.sma(df['Close'], length=14)  # Simple Moving Average
df['CORR'] = df['Close'].rolling(window=14).corr(df['SMA'])  # Correlation using pandas_ta

df.dropna(inplace=True)
df_scaled = sc.transform(df[['VOLATILITY', 'RSI', 'ADX', 'CORR']])
df['predicted_signal_4_tmrw'] = model.predict(df_scaled)
df['strategy_returns'] = df['predicted_signal_4_tmrw'].shift(1) * df['PCT_CHANGE']
df.dropna(inplace=True)

# Round the data to 5 decimal places
df = df.round(5)

# Display the backtest data using tabulate
print(tabulate(df.tail(10), headers='keys', tablefmt='pretty'))

# -------------------------------------------------------------------------------------
# Step 11: Using Pyfolio
# -------------------------------------------------------------------------------------

perf_stats = pf.timeseries.perf_stats(df.strategy_returns)

# Print the performance stats
print(perf_stats)

pf.create_simple_tear_sheet(df.strategy_returns)
plt.show()

# -------------------------------------------------------------------------------------
# THE END
# -------------------------------------------------------------------------------------
# Out:
# /tmp/ipython-input-2742935504.py:28: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2002-01-01', end='2026-01-01')
# [*********************100%***********************]  1 of 1 completed
# +---------------------+--------------------+--------------------+--------------------+--------------------+------------+
# |        Date         |       Close        |        High        |        Low         |        Open        |   Volume   |
# +---------------------+--------------------+--------------------+--------------------+--------------------+------------+
# | 2002-01-01 00:00:00 | 1.919060468673706  | 1.9190604686737058 | 1.9190604686737058 | 1.9190604686737058 |    0.0     |
# | 2002-01-02 00:00:00 | 1.9365061521530151 | 1.953952048504738  | 1.901614188021455  | 1.901614188021455  | 4236811.0  |
# | 2002-01-03 00:00:00 | 1.9365061521530151 | 1.9365061521530151 | 1.9365061521530151 | 1.9365061521530151 |    0.0     |
# | 2002-01-04 00:00:00 | 2.041182279586792  | 2.058628177947384  | 2.0237362097980656 | 2.041182279586792  | 11255576.0 |
# | 2002-01-07 00:00:00 | 2.0586278438568115 | 2.0586278438568115 | 2.006289985840707  | 2.0586278438568115 | 10752763.0 |
# +---------------------+--------------------+--------------------+--------------------+--------------------+------------+
# +---------------------+------------+----------+----------+---------+----------------+---------------+
# |        Date         | VOLATILITY |   RSI    |   ADX    |  CORR   | Returns_4_Tmrw | Actual_Signal |
# +---------------------+------------+----------+----------+---------+----------------+---------------+
# | 2002-02-06 00:00:00 |  1.50599   | 80.61118 | 64.60036 | 0.90751 |    -0.02273    |      0.0      |
# | 2002-02-07 00:00:00 |  1.74251   | 69.84147 | 63.39715 | 0.8336  |    0.00775     |      1.0      |
# | 2002-02-08 00:00:00 |  1.74233   | 71.22155 | 62.43248 | 0.77657 |      0.0       |      0.0      |
# | 2002-02-11 00:00:00 |  1.74233   | 71.22155 | 61.53672 | 0.71405 |      0.0       |      0.0      |
# | 2002-02-12 00:00:00 |  1.74233   | 71.22155 | 60.70494 | 0.64496 |      0.0       |      0.0      |
# | 2002-02-13 00:00:00 |  1.75405   | 71.22155 | 59.93258 | 0.54689 |    0.02308     |      1.0      |
# | 2002-02-14 00:00:00 |   1.7362   | 75.70777 | 59.72239 | 0.49824 |    0.00752     |      1.0      |
# | 2002-02-15 00:00:00 |  1.56625   | 76.99497 | 59.67585 | 0.46201 |      0.0       |      0.0      |
# | 2002-02-18 00:00:00 |  1.47187   | 76.99497 | 59.06987 | 0.46284 |    -0.02239    |      0.0      |
# | 2002-02-19 00:00:00 |  1.62503   | 65.00884 | 57.46616 | 0.29741 |    -0.01527    |      0.0      |
# +---------------------+------------+----------+----------+---------+----------------+---------------+
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 128)            │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,281 (67.50 KB)
#  Trainable params: 17,281 (67.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary_accuracy: 0.5403 - loss: 0.6925 - val_binary_accuracy: 0.5046 - val_loss: 0.6952
# Epoch 2/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5284 - loss: 0.6900 - val_binary_accuracy: 0.4971 - val_loss: 0.6988
# Epoch 3/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5491 - loss: 0.6851 - val_binary_accuracy: 0.4954 - val_loss: 0.6982
# Epoch 4/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5378 - loss: 0.6867 - val_binary_accuracy: 0.4979 - val_loss: 0.7033
# Epoch 5/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5286 - loss: 0.6915 - val_binary_accuracy: 0.4954 - val_loss: 0.7017
# Epoch 6/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.5385 - loss: 0.6900 - val_binary_accuracy: 0.4971 - val_loss: 0.7007
# Epoch 7/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.5398 - loss: 0.6880 - val_binary_accuracy: 0.5004 - val_loss: 0.6977
# Epoch 8/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5607 - loss: 0.6821 - val_binary_accuracy: 0.5038 - val_loss: 0.6961
# Epoch 9/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5448 - loss: 0.6860 - val_binary_accuracy: 0.4954 - val_loss: 0.7028
# Epoch 10/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5534 - loss: 0.6832 - val_binary_accuracy: 0.4945 - val_loss: 0.6981
# Epoch 11/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5548 - loss: 0.6837 - val_binary_accuracy: 0.5029 - val_loss: 0.6978
# Epoch 12/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5516 - loss: 0.6825 - val_binary_accuracy: 0.5013 - val_loss: 0.6989
# Epoch 13/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5505 - loss: 0.6828 - val_binary_accuracy: 0.4937 - val_loss: 0.7021
# Epoch 14/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5473 - loss: 0.6828 - val_binary_accuracy: 0.4987 - val_loss: 0.6990
# Epoch 15/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5609 - loss: 0.6813 - val_binary_accuracy: 0.5097 - val_loss: 0.6957
# Epoch 16/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - binary_accuracy: 0.5489 - loss: 0.6831 - val_binary_accuracy: 0.5139 - val_loss: 0.6961
# Epoch 17/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.5615 - loss: 0.6822 - val_binary_accuracy: 0.5055 - val_loss: 0.6981
# Epoch 18/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5502 - loss: 0.6839 - val_binary_accuracy: 0.4962 - val_loss: 0.7013
# Epoch 19/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5527 - loss: 0.6821 - val_binary_accuracy: 0.5038 - val_loss: 0.6989
# Epoch 20/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5560 - loss: 0.6811 - val_binary_accuracy: 0.5029 - val_loss: 0.7016
# Epoch 21/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5607 - loss: 0.6818 - val_binary_accuracy: 0.5029 - val_loss: 0.6982
# Epoch 22/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5643 - loss: 0.6781 - val_binary_accuracy: 0.5264 - val_loss: 0.6958
# Epoch 23/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5586 - loss: 0.6823 - val_binary_accuracy: 0.4954 - val_loss: 0.7017
# Epoch 24/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5630 - loss: 0.6805 - val_binary_accuracy: 0.5105 - val_loss: 0.7005
# Epoch 25/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5556 - loss: 0.6814 - val_binary_accuracy: 0.5122 - val_loss: 0.6986
# Epoch 26/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5670 - loss: 0.6772 - val_binary_accuracy: 0.5080 - val_loss: 0.6968
# Epoch 27/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - binary_accuracy: 0.5571 - loss: 0.6794 - val_binary_accuracy: 0.5080 - val_loss: 0.7001
# Epoch 28/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.5647 - loss: 0.6801 - val_binary_accuracy: 0.5139 - val_loss: 0.6996
# Epoch 29/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.5737 - loss: 0.6734 - val_binary_accuracy: 0.4979 - val_loss: 0.6993
# Epoch 30/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5602 - loss: 0.6763 - val_binary_accuracy: 0.5088 - val_loss: 0.7023
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +-----------------------+-------------------------+
# | Predicted No Position | Predicted Long Position |
# +-----------------------+-------------------------+
# |          562          |           31            |
# |          554          |           44            |
# +-----------------------+-------------------------+
#
#
#
#                precision    recall  f1-score   support
#
#            0       0.50      0.95      0.66       593
#            1       0.59      0.07      0.13       598
#
#     accuracy                           0.51      1191
#    macro avg       0.55      0.51      0.39      1191
# weighted avg       0.55      0.51      0.39      1191
# /tmp/ipython-input-2742935504.py:159: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start='2002-01-01', end='2026-01-01')
# [*********************100%***********************]  1 of 1 completed
#  49/187 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# +---------------------+-------+-------+-------+-------+-----------+------------+------------+----------+----------+----------+----------+-------------------------+------------------+
# |        Date         | Close | High  |  Low  | Open  |  Volume   | PCT_CHANGE | VOLATILITY |   RSI    |   ADX    |   SMA    |   CORR   | predicted_signal_4_tmrw | strategy_returns |
# +---------------------+-------+-------+-------+-------+-----------+------------+------------+----------+----------+----------+----------+-------------------------+------------------+
# | 2025-08-25 00:00:00 | 16.84 | 16.98 | 16.76 | 16.98 | 5002700.0 |  -0.00414  |  0.59975   | 56.96336 | 20.36953 | 16.80794 | 0.38565  |   0.4536699950695038    |     -0.00187     |
# | 2025-08-26 00:00:00 | 16.7  | 16.82 | 16.7  | 16.82 | 6938500.0 |  -0.00831  |  0.64552   | 50.36077 | 19.27456 | 16.81286 | 0.11553  |   0.46841999888420105   |     -0.00377     |
# | 2025-08-27 00:00:00 | 16.66 | 16.74 | 16.6  | 16.68 | 3961194.0 |  -0.0024   |   0.6446   | 48.62648 | 18.88309 | 16.81143 | -0.19265 |   0.44986000657081604   |     -0.00112     |
# | 2025-08-28 00:00:00 | 16.75 | 16.76 | 16.66 | 16.66 | 3543300.0 |   0.0054   |  0.63585   | 52.58306 | 18.36133 | 16.80857 | -0.26973 |   0.47290000319480896   |     0.00243      |
# | 2025-08-29 00:00:00 | 16.74 | 16.79 | 16.7  | 16.75 | 3881400.0 |  -0.0006   |  0.61574   | 52.10289 | 17.63383 | 16.79857 | -0.25537 |   0.47633999586105347   |     -0.00028     |
# | 2025-09-01 00:00:00 | 16.75 | 16.78 | 16.6  | 16.68 | 3427200.0 |   0.0006   |  0.58084   | 52.56933 | 17.60536 | 16.79857 | -0.36062 |    0.470550000667572    |     0.00028      |
# | 2025-09-02 00:00:00 | 16.85 | 16.87 | 16.74 | 16.75 | 4182200.0 |  0.00597   |  0.59544   | 57.07133 | 16.84809 | 16.80143 | -0.33828 |   0.4879100024700165    |     0.00281      |
# | 2025-09-03 00:00:00 | 16.8  | 16.9  | 16.71 | 16.85 | 3707700.0 |  -0.00297  |  0.57108   | 54.29623 | 16.3467  | 16.79286 | -0.19127 |   0.4892599880695343    |     -0.00145     |
# | 2025-09-04 00:00:00 | 16.98 | 16.98 | 16.79 | 16.79 | 6039500.0 |  0.01071   |  0.64391   | 61.54539 | 15.25167 | 16.79857 | 0.06798  |   0.44040000438690186   |     0.00524      |
# | 2025-09-05 00:00:00 | 16.92 | 17.07 | 16.88 | 17.0  | 2140800.0 |  -0.00353  |  0.53265   | 58.22995 | 14.72896 | 16.81571 | -0.1113  |   0.4897100031375885    |     -0.00156     |
# +---------------------+-------+-------+-------+-------+-----------+------------+------------+----------+----------+----------+----------+-------------------------+------------------+
# Annual return          0.069867
# Cumulative returns     3.932770
# Annual volatility      0.089152
# Sharpe ratio           0.802138
# Calmar ratio           0.338653
# Stability              0.955113
# Max drawdown          -0.206309
# Omega ratio            1.156840
# Sortino ratio          1.204879
# Skew                   0.241830
# Kurtosis               5.248376
# Tail ratio             1.104423
# Daily value at risk   -0.010948
# dtype: float64
# /usr/local/lib/python3.12/dist-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.987%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-02-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-09-05</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>283</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.987%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>393.277%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.915%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.34</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-20.631%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.24</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.25</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.095%</td>
#     </tr>
#   </tbody>
# </table>
