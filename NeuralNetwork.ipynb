# %% [markdown]
# <a href="https://colab.research.google.com/github/NOVARESTAPI/Data-streaming/blob/main/NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.4.67b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.8 MB/s eta 0:00:00
# Collecting pandas>=2.3.2 (from pandas_ta)
#   Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from pandas_ta) (4.67.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Downloading pandas_ta-0.4.67b0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 14.5 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 76.3 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 96.5 MB/s eta 0:00:00
# Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 114.7 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 16.4 MB/s eta 0:00:00
# Installing collected packages: numpy, llvmlite, pandas, numba, pandas_ta
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# Successfully installed llvmlite-0.44.0 numba-0.61.2 numpy-2.2.6 pandas-2.3.2 pandas_ta-0.4.67b0

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.3 MB/s eta 0:00:00
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
# ^C

# %%
# !pip install pyfolio-reloaded
# Out:
# Collecting pyfolio-reloaded
#   Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (2.2.2)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (3.10.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (1.16.1)
# Requirement already satisfied: scikit-learn>=0.16.1 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (1.6.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from pyfolio-reloaded) (0.13.2)
# Collecting empyrical-reloaded>=0.5.9 (from pyfolio-reloaded)
#   Downloading empyrical_reloaded-0.5.12-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded) (1.4.2)
# Collecting peewee<3.17.4 (from empyrical-reloaded>=0.5.9->pyfolio-reloaded)
#   Downloading peewee-3.17.3.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 33.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio-reloaded)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=3.2.3->pyfolio-reloaded) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.4.0->pyfolio-reloaded) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.5.0->pyfolio-reloaded) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.16.1->pyfolio-reloaded) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.16.1->pyfolio-reloaded) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio-reloaded) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio-reloaded) (1.17.0)
# Downloading pyfolio_reloaded-0.9.9-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 62.0 MB/s eta 0:00:00
# Downloading empyrical_reloaded-0.5.12-py3-none-any.whl (33 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.8 MB/s eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.3-py3-none-any.whl size=138487 sha256=64727a0fba93f49fbbf4ae2bb1943b0f221f788eea86cf320e015edf25172b55
#   Stored in directory: /root/.cache/pip/wheels/39/c7/dd/909d267742f7fbb941ff081dacd661f622a0b4eb38f667b84b
# Successfully built peewee
# Installing collected packages: peewee, jedi, empyrical-reloaded, pyfolio-reloaded
#   Attempting uninstall: peewee
#     Found existing installation: peewee 3.18.2
#     Uninstalling peewee-3.18.2:
#       Successfully uninstalled peewee-3.18.2
# Successfully installed empyrical-reloaded-0.5.12 jedi-0.19.2 peewee-3.17.3 pyfolio-reloaded-0.9.9

# %%
# -------------------------------------------------------------------------------------
# Full Ternary Label ML Pipeline + Backtest
# -------------------------------------------------------------------------------------

import numpy as np
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers
from keras.callbacks import EarlyStopping

# -------------------------------------------------------------------------------------
# Step 1: Download Data
# -------------------------------------------------------------------------------------

ticker = "YF8.SI"
data = yf.download(ticker, start="2008-01-01", end="2025-12-31")
data.columns = data.columns.droplevel(level=1)  # remove multi-level columns if present

# -------------------------------------------------------------------------------------
# Step 2: Feature Engineering
# -------------------------------------------------------------------------------------

data["RET_1d"] = data["Close"].pct_change(1)
data["RET_5d"] = data["Close"].pct_change(5)
data["RET_10d"] = data["Close"].pct_change(10)

data["SMA_5"] = data["Close"].rolling(5).mean()
data["SMA_20"] = data["Close"].rolling(20).mean()
data["SMA_ratio"] = data["SMA_5"] / data["SMA_20"]

bb = ta.bbands(data["Close"], length=20, std=2)

# Dynamically find Bollinger Band column names
if bb is not None:
    bb_upper_cols = bb.filter(like='BBU')
    bb_lower_cols = bb.filter(like='BBL')

    if not bb_upper_cols.empty and not bb_lower_cols.empty:
        bb_upper = bb_upper_cols.columns[0]
        bb_lower = bb_lower_cols.columns[0]
        data["BB_width"] = (bb[bb_upper] - bb[bb_lower]) / data["SMA_20"]
    else:
        print("Warning: Could not find Bollinger Band columns.")
        data["BB_width"] = np.nan
else:
    print("Warning: Bollinger Bands could not be calculated.")
    data["BB_width"] = np.nan


data["RSI"] = ta.rsi(data["Close"], length=14)
macd = ta.macd(data["Close"])
if macd is not None and "MACD_12_26_9" in macd.columns:
    data["MACD"] = macd["MACD_12_26_9"]
else:
    print("Warning: MACD could not be calculated.")
    data["MACD"] = np.nan

adx = ta.adx(data["High"], data["Low"], data["Close"], length=14)
if adx is not None and "ADX_14" in adx.columns:
    data["ADX"] = adx["ADX_14"]
else:
    print("Warning: ADX could not be calculated.")
    data["ADX"] = np.nan


data["VOLATILITY"] = data["RET_1d"].rolling(14).std()
data["VOL_MA"] = data["Volume"].rolling(20).mean()
data["VOL_ratio"] = data["Volume"] / data["VOL_MA"]


# -------------------------------------------------------------------------------------
# Step 3: Define Ternary Labels (5-day forward returns)
# -------------------------------------------------------------------------------------

horizon = 5 # 5 days forward
data["Fwd_Returns"] = data["Close"].pct_change(horizon).shift(-horizon)

# Define thresholds (e.g., top 30% and bottom 30% of returns)
up_thresh = data["Fwd_Returns"].quantile(0.7)
down_thresh = data["Fwd_Returns"].quantile(0.3)

def label_return_ternary(r):
    if r > up_thresh:
        return 1   # Up
    elif r < down_thresh:
        return 0  # Down
    else:
        return -1 # Neutral

data["Signal_ternary"] = data["Fwd_Returns"].apply(label_return_ternary)

# -------------------------------------------------------------------------------------
# Step 4: Prepare Dataset (drop NA and neutral labels)
# -------------------------------------------------------------------------------------

features = [
    "RET_1d","RET_5d","RET_10d",
    "SMA_ratio","BB_width","RSI","MACD","ADX",
    "VOLATILITY","VOL_ratio"
]

df = data.dropna().copy() # Use .copy() to avoid SettingWithCopyWarning
df = df[df["Signal_ternary"] != -1].copy() # Drop neutral labels and use .copy()

X = df[features]
y = df["Signal_ternary"] # Use ternary signal

# Convert labels to one-hot encoding for Keras
y = pd.get_dummies(y, prefix="Signal").values

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# -------------------------------------------------------------------------------------
# Step 5: Define Model
# -------------------------------------------------------------------------------------

model = Sequential()
model.add(Dense(64, activation="relu", input_dim=X_train.shape[1],
                kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(32, activation="relu",
                kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(y_train.shape[1], activation="softmax")) # Softmax for ternary classification

model.compile(optimizer="adam",
              loss="categorical_crossentropy", # Categorical crossentropy for ternary classification
              metrics=["accuracy"])

# -------------------------------------------------------------------------------------
# Step 6: Train Model
# -------------------------------------------------------------------------------------

early_stop = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=32,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stop])

# -------------------------------------------------------------------------------------
# Step 7: Training Curves
# -------------------------------------------------------------------------------------

plt.figure(figsize=(10,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history["accuracy"], label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.show()

# -------------------------------------------------------------------------------------
# Step 8: Evaluation on Test Set
# -------------------------------------------------------------------------------------

y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1) # Get predicted class index

# Convert y_test back from one-hot for confusion matrix and classification report
y_test_labels = np.argmax(y_test, axis=1)

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, y_pred))
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred))

# -------------------------------------------------------------------------------------
# Step 9: Backtest with Full Dataset
# -------------------------------------------------------------------------------------

# Use all data (including neutral) for predictions
df_all = data.dropna().copy() # Use .copy() to avoid SettingWithCopyWarning
X_all = sc.transform(df_all[features])
df_all["pred_prob"] = list(model.predict(X_all)) # Store probabilities as a list of arrays
df_all["pred_signal"] = np.argmax(model.predict(X_all), axis=1) # Get predicted class index

# Map predicted index back to original labels (0: Down, 1: Up)
# Note: This assumes the one-hot encoding order is consistent.
# If the order is not guaranteed, you might need to store the mapping.
label_mapping = {0: 0, 1: 1} # Assuming 0 is Down, 1 is Up after one-hot encoding
df_all["pred_signal_mapped"] = df_all["pred_signal"].map(label_mapping)


# Strategy: Long if pred_signal=1, Short if pred_signal=0, Neutral if pred_signal=-1 (or not in mapping)
# For simplicity in backtest, assuming we can short. In reality, this might need adjustment.
# Filter out neutral signals for strategy returns calculation
df_strategy = df_all[df_all["Signal_ternary"] != -1].copy() # Use .copy() to avoid SettingWithCopyWarning

df_strategy["strategy_returns"] = np.where(df_strategy["pred_signal_mapped"]==1,
                                      df_strategy["RET_1d"], -df_strategy["RET_1d"])


# Cumulative returns for strategy and buy & hold (using original data for buy & hold)
df_all["cum_buyhold"] = (1 + df_all["RET_1d"]).cumprod()

# -------------------------------------------------------------------------------------
# Step 10: Plot Backtest Results
# -------------------------------------------------------------------------------------

plt.figure(figsize=(12,6))
plt.plot(df_strategy.index, df_strategy["strategy_returns"], label="Strategy")
plt.plot(df_all.index, df_all["cum_buyhold"], label="Buy & Hold", linestyle="--")
plt.title(f"Backtest: {ticker}")
plt.ylabel("Cumulative Returns")
plt.legend()
plt.show()

# Show last 10 days of signals
print(df_all[["Close", "Signal_ternary", "pred_signal_mapped", "Fwd_Returns"]].tail(10))
# Out:
# /tmp/ipython-input-3306974294.py:24: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2008-01-01", end="2025-12-31")
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.4713 - loss: 0.7888 - val_accuracy: 0.5895 - val_loss: 0.7112
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4840 - loss: 0.7610 - val_accuracy: 0.4947 - val_loss: 0.7853
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5546 - loss: 0.7423 - val_accuracy: 0.5053 - val_loss: 0.8032
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5258 - loss: 0.7461 - val_accuracy: 0.5368 - val_loss: 0.7863
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5788 - loss: 0.7235 - val_accuracy: 0.4947 - val_loss: 0.7656
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5193 - loss: 0.7296 - val_accuracy: 0.5053 - val_loss: 0.7608
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6003 - loss: 0.7145 - val_accuracy: 0.5158 - val_loss: 0.7602
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6411 - loss: 0.6934 - val_accuracy: 0.5263 - val_loss: 0.7307
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6185 - loss: 0.7067 - val_accuracy: 0.5368 - val_loss: 0.7245
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6064 - loss: 0.7049 - val_accuracy: 0.5579 - val_loss: 0.7199
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6507 - loss: 0.6880 - val_accuracy: 0.5579 - val_loss: 0.7201
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Confusion Matrix:
# [[13  9]
#  [30 43]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.59      0.40        22
#            1       0.83      0.59      0.69        73
#
#     accuracy                           0.59        95
#    macro avg       0.56      0.59      0.54        95
# weighted avg       0.71      0.59      0.62        95
#
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Price       Close  Signal_ternary  pred_signal_mapped  Fwd_Returns
# Date
# 2025-08-18   1.06              -1                   1    -0.009434
# 2025-08-19   1.04               1                   1     0.019231
# 2025-08-20   1.02               1                   1     0.029412
# 2025-08-21   1.02              -1                   1     0.009804
# 2025-08-22   1.03               1                   1     0.019417
# 2025-08-25   1.05               1                   1     0.038095
# 2025-08-26   1.06              -1                   1     0.009434
# 2025-08-27   1.05               1                   1     0.019048
# 2025-08-28   1.03               1                   1     0.019417
# 2025-08-29   1.05              -1                   1     0.000000

# %%
print("Shape of original data:")
print(data.shape)
print("\nColumns in original data:")
print(data.columns)
print("\nNumber of NA values per column:")
print(data.isnull().sum())
print("\nValue counts of Signal_ternary before dropping neutral:")
print(data["Signal_ternary"].value_counts())

print("\nShape of df after dropping NA and neutral:")
print(df.shape)
print("\nValue counts of Signal_ternary in df:")
print(df["Signal_ternary"].value_counts())
# Out:
# Shape of original data:
# (842, 20)
#
# Columns in original data:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'RET_1d', 'RET_5d', 'RET_10d',
#        'SMA_5', 'SMA_20', 'SMA_ratio', 'BB_width', 'RSI', 'MACD', 'ADX',
#        'VOLATILITY', 'VOL_MA', 'VOL_ratio', 'Fwd_Returns', 'Signal_ternary'],
#       dtype='object', name='Price')
#
# Number of NA values per column:
# Price
# Close              0
# High               0
# Low                0
# Open               0
# Volume             0
# RET_1d             1
# RET_5d             5
# RET_10d           10
# SMA_5              4
# SMA_20            19
# SMA_ratio         19
# BB_width          19
# RSI                1
# MACD              25
# ADX               13
# VOLATILITY        14
# VOL_MA            19
# VOL_ratio         19
# Fwd_Returns        5
# Signal_ternary     0
# dtype: int64
#
# Value counts of Signal_ternary before dropping neutral:
# Signal_ternary
# -1    346
#  0    250
#  1    246
# Name: count, dtype: int64
#
# Shape of df after dropping NA and neutral:
# (473, 20)
#
# Value counts of Signal_ternary in df:
# Signal_ternary
# 0    240
# 1    233
# Name: count, dtype: int64
